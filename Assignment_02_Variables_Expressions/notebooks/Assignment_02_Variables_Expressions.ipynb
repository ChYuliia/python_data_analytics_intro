# %% [markdown]
# **Instructions (this notebook):**
#
# 1. **Make the first notebook cell a Markdown cell with your name and date.**
# 2. **Write a program to prompt the user for hours and rate per hour using input to compute gross pay.**
# 3. **Use 35 hours and a rate of 2.75 per hour to test the program (the pay should be 96.25).**
# 4. **You should use input to read a string and float() to convert the string to a number.**
# 5. **Do not worry about error checking or bad user data.**

# %% [markdown]
# ## Yuliia Chernysheva
# ### Date: January 24, 2026

# %%
hours_worked = float(input("Enter hours:"))
hourly_rate = float(input("Enter rate per hour:"))
gross_pay = hours_worked * hourly_rate
print("Hours worked =", hours_worked, "\nRate per hour =", hourly_rate)
print("-" * 25)
print(f"Gross pay = {gross_pay:.2f}")
# Out:
# Enter hours: 35
# Enter rate per hour: 2.75
# Hours worked = 35.0
# Rate per hour = 2.75
# -------------------------
# Gross pay = 96.25

# %%
hours_worked = 35
hourly_rate = 2.75
gross_pay = hours_worked * hourly_rate
print("Hours worked =", hours_worked, "\nRate per hour =", hourly_rate)
print("-" * 20)
print(f"Gross pay = {gross_pay:.2f}")
# Out:
# Hours worked = 35
# Rate per hour = 2.75
# --------------------
# Gross pay = 96.25

# %% [markdown]
# ### Test
# Program tested with:
# - Hours: 35
# - Rate per hour: 2.75
# Output: Gross pay = 96.25
